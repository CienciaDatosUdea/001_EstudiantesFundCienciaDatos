# %%
from datascience import *
import matplotlib.pylab as plt
import numpy as np
import plotly.express as px
import pandas as pd

# %% [markdown]
# # Operaciones group y pivot

# %%
# Crear la tabla con más filas
tabla_frutas = Table().with_columns(
    'Fruta', np.array(['manzana', 'pera', 'manzana', 'fresa', 'pera', 'fresa', 
                       'banano', 'mango', 'kiwi', 'banano', 'mango', 'fresa', 
                       'kiwi', 'pera', 'banano', 'manzana', 'pera', 'fresa', 
                       'mango', 'manzana']),
    'Color', np.array(['rojo', 'verde', 'verde', 'rojo', 'verde', 'rojo', 
                       'verde', 'naranja', 'verde', 'amarillo', 'naranja', 'rojo', 
                       'verde', 'verde', 'amarillo', 'rojo', 'verde', 'rojo', 
                       'naranja', 'rojo']),
    'Precio', np.array([2500, 3500, 2500, 4000, 3500, 4000, 
                              1500, 3000, 4500, 1500, 3000, 4000, 
                              4500, 3500, 1500, 2500, 3500, 4000, 
                              3000, 2500])
)

# %%
tabla_frutas.group(["Fruta", "Color"], np.mean)
# Out:
# Fruta   | Color    | Precio mean
# banano  | amarillo | 1500
# banano  | verde    | 1500
# fresa   | rojo     | 4000
# kiwi    | verde    | 4500
# mango   | naranja  | 3000
# manzana | rojo     | 2500
# manzana | verde    | 2500
# pera    | verde    | 3500

# %%
tabla_frutas.pivot("Fruta", "Color")
# Out:
# Color    | banano | fresa | kiwi | mango | manzana | pera
# amarillo | 2      | 0     | 0    | 0     | 0       | 0
# naranja  | 0      | 0     | 0    | 3     | 0       | 0
# rojo     | 0      | 4     | 0    | 0     | 3       | 0
# verde    | 1      | 0     | 2    | 0     | 1       | 4

# %%
tabla_frutas.pivot("Fruta", "Color", values="Precio", collect=np.mean)
# Out:
# Color    | banano | fresa | kiwi | mango | manzana | pera
# amarillo | 1500   | 0     | 0    | 0     | 0       | 0
# naranja  | 0      | 0     | 0    | 3000  | 0       | 0
# rojo     | 0      | 4000  | 0    | 0     | 2500    | 0
# verde    | 1500   | 0     | 4500 | 0     | 2500    | 3500

# %% [markdown]
# # Libros

# %%
from datascience import *

# Crear la tabla con 20 libros
libros = Table().with_columns(
    'Titulo', make_array(
        'Cien Años de Soledad', 'El Quijote', '1984', 'Orgullo y Prejuicio', 'Crimen y Castigo', 
        'El Principito', 'Don Juan Tenorio', 'Matar a un Ruiseñor', 'La Odisea', 'El Gran Gatsby',
        'Fahrenheit 451', 'La Metamorfosis', 'El Retrato de Dorian Gray', 'Hamlet', 'Macbeth',
        'La Ilíada', 'El Señor de los Anillos', 'Drácula', 'Los Miserables', 'La Divina Comedia'),
    
    'Autor', make_array(
        'Gabriel García Márquez', 'Miguel de Cervantes', 'George Orwell', 'Jane Austen', 'Fiódor Dostoyevski', 
        'Antoine de Saint-Exupéry', 'José Zorrilla', 'Harper Lee', 'Homero', 'F. Scott Fitzgerald', 
        'Ray Bradbury', 'Franz Kafka', 'Oscar Wilde', 'William Shakespeare', 'William Shakespeare',
        'Homero', 'J. R. R. Tolkien', 'Bram Stoker', 'Victor Hugo', 'Dante Alighieri'),
    
    'Genero', make_array(
        'Ficción', 'Clásico', 'Ciencia Ficción', 'Romance', 'Clásico', 
        'Ficción', 'Clásico', 'Ficción', 'Clásico', 'Ficción',
        'Ciencia Ficción', 'Ficción', 'Clásico', 'Clásico', 'Clásico',
        'Clásico', 'Fantasía', 'Terror', 'Clásico', 'Clásico'),
    
    'Precio (COP)', make_array(
        45000, 60000, 40000, 38000, 52000, 
        35000, 30000, 45000, 32000, 42000,
        37000, 25000, 48000, 51000, 50000,
        30000, 70000, 35000, 68000, 63000),
    
    'Anio de Publicacion', make_array(
        1967, 1605, 1949, 1813, 1866,
        1943, 1844, 1960, 'Siglo VIII a.C.', 1925,
        1953, 1915, 1890, 1603, 1606,
        'Siglo VIII a.C.', 1954, 1897, 1862, 1320),
    
    'Calificacion (1-5)', make_array(
        4.8, 4.9, 4.7, 4.6, 4.8, 
        4.7, 4.4, 4.9, 4.6, 4.8,
        4.6, 4.5, 4.7, 4.9, 4.8,
        4.6, 4.9, 4.7, 4.9, 4.9)
)

# %%
libros.group("Genero", np.mean)
# Out:
# Genero          | Titulo mean | Autor mean | Precio (COP) mean | Anio de Publicacion mean | Calificacion (1-5) mean
# Ciencia Ficción |             |            | 38500             |                          | 4.65
# Clásico         |             |            | 48400             |                          | 4.75
# Fantasía        |             |            | 70000             |                          | 4.9
# Ficción         |             |            | 38400             |                          | 4.74
# Romance         |             |            | 38000             |                          | 4.6
# Terror          |             |            | 35000             |                          | 4.7

# %%
libros.where("Genero", are.equal_to("Clásico")).column("Precio (COP)").sum()
# Out:
# 484000

# %% [markdown]
# # Joins

# %%
# Tabla de estudiantes con IDs y nombres
students = Table().with_columns(
    'ID', [1, 2, 3, 4],
    'Name', ['Alice', 'Bob', 'Charlie', 'David']
)

# Tabla de calificaciones con IDs y calificaciones
grades = Table().with_columns(
    'ID', [1, 2, 3, 5],
    'Grade', ['A', 'B', 'C', 'D']
)

# Realizar un join en la columna 'ID'
merged_table = students.join('ID', grades)

# Mostrar la tabla resultante
merged_table.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ID</th> <th>Name</th> <th>Grade</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1   </td> <td>Alice  </td> <td>A    </td>
#         </tr>
#         <tr>
#             <td>2   </td> <td>Bob    </td> <td>B    </td>
#         </tr>
#         <tr>
#             <td>3   </td> <td>Charlie</td> <td>C    </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# # Ejercicios de clase árboles udea

# %% [markdown]
# ## Árboles de la Universidad de Antioquia
#
# En este ejercicio exploraremos un conjunto de datos con información sobre árboles localizados en el campus de la Universidad de Antioquia.
# Aplicaremos operaciones de filtrado, agrupamiento, exploración de especies y visualización geográfica.
#
# 1. Lee el archivo `arboles_udea_localizacion.csv` en una tabla llamada `arboles` y selecciona las columnas:
# `"FAMILIA"`, `"Nombre común"`, `"Nombre científico"`, `"X"`, `"Y"`, `"ALTURA TOTAL"`, `"ALTURA DE COPA"`, `"DIAMETRO_MAYOR "`, `"DIAMETRO_MENOR"`.
#
#
#
# 2. Muestra los nombres de las columnas de la tabla.
# ¿Qué función utilizas para hacerlo?
#
#
#
# 3. Filtra los árboles cuya **altura total** sea mayor a 20 metros.
# ¿Cuántos árboles cumplen con esta condición?
#
#
#
# 4. Agrupa la tabla por la columna `"FAMILIA"` y calcula el **promedio de altura total** para cada familia.
# Muestra el resultado ordenado de mayor a menor.
#
#
#
# 5. ¿Qué familia tiene la **mayor altura promedio**?
# ¿Y cuál tiene la **menor altura promedio**?
#
#
# 6. Muestra los nombres comunes de todas las especies presentes en el conjunto de datos.
# ¿Qué función utilizas para obtener una lista sin repeticiones?
#
#
#
# 7. Filtra únicamente los árboles de la familia `"MORACEAE"` y realiza una tabla pivote (`pivot`) con la familia en las filas y el nombre común en las columnas.
# ¿Qué observas en el resultado?
#
#
# 8. Convierte la tabla `arboles_udea` en un `DataFrame` de pandas con las columnas `"Y"`, `"X"` y `"Nombre común"`.
# Guárdalo en una variable llamada `data_arboles`.
#
# ```
# import pandas as pd
# data_arboles = arboles_udea.select('Y', 'X', 'Nombre común').to_df()
# ```
#
# 9. Utiliza `plotly.express` para crear un **mapa interactivo** con los puntos que representan la ubicación de los árboles.
# Cada punto debe mostrar el nombre común al pasar el cursor.
#
# - ¿Qué parámetro define el color de los puntos?
# - ¿Qué parámetro controla el nivel de zoom?
# - ¿Qué representa cada punto verde en el mapa?
#
# Ayuda:
#     ```python
#     fig = px.scatter_mapbox(
#         data_arboles,
#         lat='X',
#         lon='Y',
#         hover_name='Nombre común',
#         color_discrete_sequence=['green'],
#         zoom=16,
#         height=600,
#         title='Mapa interactivo de árboles sobre OpenStreetMap'
#     )
#     fig.update_layout(mapbox_style='open-street-map')
#     fig.show()
#     ```
#
#
#
#
# 10. Modifica el mapa cambiando el estilo de fondo (`mapbox_style`).
# ¿Qué otros estilos gratuitos puedes usar además de `'open-street-map'`?

# %%
arboles = Table().read_table("arboles_udea_localizacion.csv")
arboles.labels
arboles_udea = arboles.select("FAMILIA", "Nombre común","Nombre científico", "X", "Y",'ALTURA TOTAL',
 'ALTURA DE COPA',
 'DIAMETRO_MAYOR ',
 'DIAMETRO_MENOR',)
arboles_udea.where("ALTURA TOTAL", are.above(20))

arboles_udea.group("FAMILIA", np.mean).select("FAMILIA","ALTURA TOTAL mean" ).sort("ALTURA TOTAL mean")


familia_mean_altura = arboles_udea.group("FAMILIA", np.mean).select("FAMILIA","ALTURA TOTAL mean" ).sort("ALTURA TOTAL mean")
familia_mean_altura.sort("ALTURA TOTAL mean", descending=True).show(50)


np.unique(arboles_udea.column("Nombre común"))

arboles_udea.where("FAMILIA", are.equal_to("MORACEAE")).pivot("FAMILIA","Nombre común")

data_arboles = arboles_udea.select('Y', 'X', 'Nombre común').to_df()
# Crear mapa
fig = px.scatter_mapbox(
    data_arboles,
    lat='X',
    lon='Y',
    hover_name='Nombre común',
    color_discrete_sequence=['green'],
    zoom=16,
    height=600,
    title='Mapa interactivo de árboles sobre OpenStreetMap'
)
# Configurar estilo base (gratuito)
fig.update_layout(mapbox_style='open-street-map')
fig.show()
# Out:
# FAMILIA          | ALTURA TOTAL mean
# CYCADACEAE       | 0.992857
# SOLANACEAE       | 2.85745
# FAGACEAE         | 3.025
# ZYGOPHYLLACEAE   | 3.03594
# APOCYNACEAE      | 3.64815
# CHRYSOBALANACEAE | 3.9
# VERBENACEAE      | 3.96364
# RUTACEAE         | 4.07447
# MELASTOMATACEAE  | 4.1
# CAPPARACEAE      | 4.1
# ... (46 rows omitted)

# %%
familia_mean_altura = arboles_udea.group("FAMILIA", np.mean).select("FAMILIA","ALTURA TOTAL mean" ).sort("ALTURA TOTAL mean")
familia_mean_altura.sort("ALTURA TOTAL mean", descending=True).show(50)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>FAMILIA</th> <th>ALTURA TOTAL mean</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>MORACEAE       </td> <td>19.1281          </td>
#         </tr>
#         <tr>
#             <td>ARAUCARIACEAE  </td> <td>16.5714          </td>
#         </tr>
#         <tr>
#             <td>ANACARDIACEAE  </td> <td>14.7288          </td>
#         </tr>
#         <tr>
#             <td>OLEACEAE       </td> <td>14.7224          </td>
#         </tr>
#         <tr>
#             <td>MELIACEAE      </td> <td>13.3057          </td>
#         </tr>
#         <tr>
#             <td>POLYGONACEAE   </td> <td>12.5409          </td>
#         </tr>
#         <tr>
#             <td>URTICACEAE     </td> <td>12.1426          </td>
#         </tr>
#         <tr>
#             <td>COMBRETACEAE   </td> <td>11.5367          </td>
#         </tr>
#         <tr>
#             <td>CALOPHYLLACEAE </td> <td>11.1143          </td>
#         </tr>
#         <tr>
#             <td>CASUARINACEAE  </td> <td>10.9             </td>
#         </tr>
#         <tr>
#             <td>LYTHRACEAE     </td> <td>10.6093          </td>
#         </tr>
#         <tr>
#             <td>ARALIACEAE     </td> <td>10.5             </td>
#         </tr>
#         <tr>
#             <td>POACEAE        </td> <td>10.5             </td>
#         </tr>
#         <tr>
#             <td>BORAGINACEAE   </td> <td>10.4457          </td>
#         </tr>
#         <tr>
#             <td>ARECACEAE      </td> <td>9.84289          </td>
#         </tr>
#         <tr>
#             <td>FABACEAE       </td> <td>9.66342          </td>
#         </tr>
#         <tr>
#             <td>SAPINDACEAE    </td> <td>9.62321          </td>
#         </tr>
#         <tr>
#             <td>ACANTHACEAE    </td> <td>8.85             </td>
#         </tr>
#         <tr>
#             <td>LAMIACEAE      </td> <td>8.78571          </td>
#         </tr>
#         <tr>
#             <td>CLUSIACEAE     </td> <td>8.76471          </td>
#         </tr>
#         <tr>
#             <td>SIMAROUBACEAE  </td> <td>8.5              </td>
#         </tr>
#         <tr>
#             <td>LECYTHIDACEAE  </td> <td>8.43696          </td>
#         </tr>
#         <tr>
#             <td>PHYLLANTHACEAE </td> <td>8.4              </td>
#         </tr>
#         <tr>
#             <td>MALVACEAE      </td> <td>8.23919          </td>
#         </tr>
#         <tr>
#             <td>BIGNONIACEAE   </td> <td>7.77442          </td>
#         </tr>
#         <tr>
#             <td>SAPOTACEAE     </td> <td>7.40714          </td>
#         </tr>
#         <tr>
#             <td>BURSERACEAE    </td> <td>7.2              </td>
#         </tr>
#         <tr>
#             <td>EBENACEAE      </td> <td>7.17143          </td>
#         </tr>
#         <tr>
#             <td>SALICACEAE     </td> <td>6.83             </td>
#         </tr>
#         <tr>
#             <td>MORINGACEAE    </td> <td>6.65             </td>
#         </tr>
#         <tr>
#             <td>PERACEAE       </td> <td>6.5              </td>
#         </tr>
#         <tr>
#             <td>ANNONACEAE     </td> <td>6.48333          </td>
#         </tr>
#         <tr>
#             <td>PROTEACEAE     </td> <td>6.31667          </td>
#         </tr>
#         <tr>
#             <td>MYRTACEAE      </td> <td>5.84503          </td>
#         </tr>
#         <tr>
#             <td>ROSACEAE       </td> <td>5.8              </td>
#         </tr>
#         <tr>
#             <td>EUPHORBIACEAE  </td> <td>5.73187          </td>
#         </tr>
#         <tr>
#             <td>BIXACEAE       </td> <td>5.65             </td>
#         </tr>
#         <tr>
#             <td>MALPIGHIACEAE  </td> <td>5.51607          </td>
#         </tr>
#         <tr>
#             <td>OCHNACEAE      </td> <td>5.4              </td>
#         </tr>
#         <tr>
#             <td>LAURACEAE      </td> <td>5.12788          </td>
#         </tr>
#         <tr>
#             <td>PODOCARPACEAE  </td> <td>4.9              </td>
#         </tr>
#         <tr>
#             <td>RUBIACEAE      </td> <td>4.64595          </td>
#         </tr>
#         <tr>
#             <td>RHAMNACEAE     </td> <td>4.6              </td>
#         </tr>
#         <tr>
#             <td>nan            </td> <td>4.5              </td>
#         </tr>
#         <tr>
#             <td>MAGNOLIACEAE   </td> <td>4.45714          </td>
#         </tr>
#         <tr>
#             <td>OXALIDACEAE    </td> <td>4.31             </td>
#         </tr>
#         <tr>
#             <td>CAPPARACEAE    </td> <td>4.1              </td>
#         </tr>
#         <tr>
#             <td>MELASTOMATACEAE</td> <td>4.1              </td>
#         </tr>
#         <tr>
#             <td>RUTACEAE       </td> <td>4.07447          </td>
#         </tr>
#         <tr>
#             <td>VERBENACEAE    </td> <td>3.96364          </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (6 rows omitted)</p>

# %%
np.unique(arboles_udea.column("Nombre común"))
# Out:
# array(['Abarco', 'Acacia amarilla', 'Acacia amarilla (1)',
#        'Acacia ferrugínea', 'Acacia mangium', 'Acacia roja',
#        'Acacia rosada', 'Aceite María', 'Achiote', 'Aegiphila', 'Aguacate',
#        'Aguacatillo', 'Alcanfor', 'Algarrobo', 'Allophyllus', 'Alma negra',
#        'Almanegra', 'Almendro', 'Almirajo', 'Almirajó', 'Annona sp.',
#        'Araucaria', 'Arazá', 'Arizá', 'Arroz con coco', 'Astrocarium',
#        'Atalea sp.', 'Azahar de la india', 'Azuceno', 'Azuceno de monte',
#        'Bala de cañón', 'Balaustre', 'Balsamo', 'Barbasco', 'Barrigón',
#        'Bischofia', 'Brownea ucayalina', 'Búcaro', 'Caballero de la noche',
#        'Cabo de hacha', 'Cacao', 'Cacao de monte', 'Caimito',
#        'Calistemo blanco', 'Calistemo rojo', 'Camajón',
#        'Canastilla rosada', 'Canelo', 'Canime', 'Canistel', 'Caobo',
#        'Capitancillo', 'Capote', 'Caracolí', 'Carambolo', 'Carbonero',
#        'Carbonero ', 'Carbonero (2)', 'Carbonero de pluma',
#        'Carbonero zorro', 'Cariseco', 'Carmín', 'Carreto',
#        'Casco de vaca blanco', 'Casco de vaca orquidea', 'Casuarina',
#        'Catape', 'Catelisoto', 'Cativo', 'Catostemma', 'Cedrillo', 'Cedro',
#        'Cedro amarillo', 'Cedro güino', 'Cedro macho', 'Cedro misionero',
#        'Cedro rosado de la india', 'Ceiba Tolúa', 'Ceiba de tierra fria',
#        'Ceiba pentandra', 'Ceiba rosada', 'Ceiba tronadora', 'Ceiba verde',
#        'Cerezo del gobernador', 'Chagualo', 'Cheflera', 'Chiminango',
#        'Chirimoya', 'Chocho', 'Choibá', 'Chumbimbo', 'Ciruela costeña',
#        'Ciruelo', 'Clavellino', 'Clitoria', 'Clusia', 'Cococristal',
#        'Comino', 'Comino crespo', 'Confite', 'Copoazú', 'Coralillo',
#        'Cortés amarillo', 'Costilla danto', 'Cotoprix', 'Cucharo', 'Cyca',
#        'Cynometra', 'Cámbulo', 'Dahlstedtia colombiana', 'Desconocido',
#        'Dinde', 'Dividivi', 'Duranta arbórea', 'Durazno de monte',
#        'Embira', 'Estrella de oriente', 'Eucalipto', 'Falso caucho',
#        'Falso laurel', 'Falso pimiento', 'Ficus', 'Ficus pandurata',
#        'Fierrillo', 'Flor de reina', 'Florisanto', 'Francesino',
#        'Frangipán', 'Grosello', 'Guacamayo', 'Guacharaco', 'Guacimo',
#        'Guadua', 'Gualanday', 'Gualanday (2)', 'Guamo', 'Guamo bejuco',
#        'Guamo machete', 'Guamo macheto', 'Guanabano', 'Guanabano macho',
#        'Guanábano', 'Guayaba ciruela', 'Guayabo', 'Guayabo campomanesia',
#        'Guayabo jaboticaba', 'Guayacan trebol', 'Guayacán amarillo',
#        'Guayacán azul', 'Guayacán bola', 'Guayacán de manizales',
#        'Guayacán peludo', 'Guayacán rosado', 'Guácimo colorado', 'Hamelia',
#        'Huesito', 'Huevo vegetal', 'Iguano', 'Inchi', 'Indio desnudo',
#        'Jagua', 'Júpiter', 'Laurel', 'Liberal', 'Licania', 'Limón',
#        'Lluvia de oro', 'Lomo de caimán', 'Macadamia', 'Macondo',
#        'Madroño', 'Magnolio', 'Majagua', 'Mamey', 'Mamoncillo',
#        'Mandarino', 'Mango', 'Mango matasano', 'Manzana kei de sudáfrica',
#        'Marañón', 'Mataraton', 'Membrillo', 'Mickey mouse', 'Miconia',
#        'Moringa', 'Mula muerta', 'Naranjo', 'Naranjo agrio', 'Navajuelo',
#        'Nazareno', 'Nogal cafetero', 'Noro', 'Níspero costeño',
#        'Níspero del Japón', 'Olivito', 'Pacó', 'Palma Bismarckia',
#        'Palma Phenix', 'Palma abanico', 'Palma abanico (2)',
#        'Palma abanico de Fijí', 'Palma abanico de la china', 'Palma areca',
#        'Palma arenga', 'Palma chonta', 'Palma chontaduro',
#        'Palma cola de zorro', 'Palma corozo del Orinoco',
#        'Palma de Madagascar', 'Palma de coco', 'Palma de vino',
#        'Palma escoba', 'Palma manila', 'Palma milpesos', 'Palma payanesa',
#        'Palma pindo', 'Palma real', 'Palma robeleni', 'Palma sancona',
#        'Palma sancona (1)', 'Palma táparo', 'Palo cruz', 'Palo zorrillo',
#        'Papayuelo', 'Parasiempre', 'Pavo real', 'Peregrina',
#        'Pero de agua', 'Pino chaquiro', 'Pisquín', 'Piñón de oreja',
#        'Pomo', 'Punta guayabo', 'Quararibea', 'Quebracho', 'Quiebra hacha',
#        'Quiebrabarrigo', 'Rayo', 'Roble', 'Rosa de monte', 'Samán',
#        'Sande Mora', 'Sietecueros', 'Simira', 'Suribio', 'Tachuelo',
#        'Tamarindo', 'Tamarindo de monte', 'Tambor', 'Teca', 'Terminalia',
#        'Totumito', 'Totumo', 'Trompeta rosa', 'Trompillo',
#        'Tulipán africano', 'Urapán', 'Uvito de playa', 'Vara santa',
#        'Velero', 'Vitex', 'Wettinia', 'Yarumo', 'Ylang-ylang', 'Yopo',
#        'Zapote', 'Zapote de carne', 'Zapote negro', 'Ziziphus',
#        'Árbol del caucho', 'Árbol del pan', 'Árbol murciélago',
#        'Árbol salchicha', 'Ébano'],
#       dtype='<U25')

# %%
arboles_udea
# Out:
# FAMILIA       | Nombre común   | Nombre científico    | X       | Y        | ALTURA TOTAL | ALTURA DE COPA | DIAMETRO_MAYOR  | DIAMETRO_MENOR
# MORACEAE      | Falso laurel   | Ficus benjamina      | 6.2691  | -75.5665 | 24           | 7.5            | 42.6            | 38.5
# ANACARDIACEAE | Mango          | Mangifera indica     | 6.26902 | -75.5665 | 6.8          | 2.6            | 12.3            | 9.2
# FABACEAE      | Carbonero (2)  | Calliandra pittieri  | 6.26898 | -75.5666 | 4.8          | 1.8            | 14.5            | 10.3
# MORACEAE      | Falso laurel   | Ficus benjamina      | 6.26891 | -75.5666 | 25           | 10             | 45.8            | 36.4
# MORACEAE      | Falso laurel   | Ficus benjamina      | 6.26881 | -75.5666 | 24           | 4              | 34.4            | 26.5
# FABACEAE      | Cedro amarillo | Albizia guachapele   | 6.26869 | -75.5666 | 8            | 4              | 10.2            | 5.1
# MYRTACEAE     | Grosello       | Eugenia uniflora     | 6.2687  | -75.5667 | 4.3          | 2.7            | 5.3             | 2.1
# MORACEAE      | Falso laurel   | Ficus benjamina      | 6.2686  | -75.5666 | 25           | 8              | 35.2            | 28.9
# MORACEAE      | Falso laurel   | Ficus benjamina      | 6.26842 | -75.5667 | 27           | 9              | 41.6            | 36.4
# FABACEAE      | Cedro amarillo | Albizia guachapele   | 6.2684  | -75.5667 | 9            | 3.7            | 13.25           | 8.5
# ... (2647 rows omitted)

# %%
arboles_udea.where("FAMILIA", are.equal_to("MORACEAE")).pivot("FAMILIA","Nombre común")
# Out:
# Nombre común    | MORACEAE
# Dinde           | 1
# Falso caucho    | 7
# Falso laurel    | 54
# Ficus           | 1
# Ficus pandurata | 3
# Sande Mora      | 4
# Árbol del pan   | 3

# %%
arboles_udea
# Out:
# FAMILIA       | Nombre común   | Nombre científico    | X       | Y        | ALTURA TOTAL | ALTURA DE COPA | DIAMETRO_MAYOR  | DIAMETRO_MENOR
# MORACEAE      | Falso laurel   | Ficus benjamina      | 6.2691  | -75.5665 | 24           | 7.5            | 42.6            | 38.5
# ANACARDIACEAE | Mango          | Mangifera indica     | 6.26902 | -75.5665 | 6.8          | 2.6            | 12.3            | 9.2
# FABACEAE      | Carbonero (2)  | Calliandra pittieri  | 6.26898 | -75.5666 | 4.8          | 1.8            | 14.5            | 10.3
# MORACEAE      | Falso laurel   | Ficus benjamina      | 6.26891 | -75.5666 | 25           | 10             | 45.8            | 36.4
# MORACEAE      | Falso laurel   | Ficus benjamina      | 6.26881 | -75.5666 | 24           | 4              | 34.4            | 26.5
# FABACEAE      | Cedro amarillo | Albizia guachapele   | 6.26869 | -75.5666 | 8            | 4              | 10.2            | 5.1
# MYRTACEAE     | Grosello       | Eugenia uniflora     | 6.2687  | -75.5667 | 4.3          | 2.7            | 5.3             | 2.1
# MORACEAE      | Falso laurel   | Ficus benjamina      | 6.2686  | -75.5666 | 25           | 8              | 35.2            | 28.9
# MORACEAE      | Falso laurel   | Ficus benjamina      | 6.26842 | -75.5667 | 27           | 9              | 41.6            | 36.4
# FABACEAE      | Cedro amarillo | Albizia guachapele   | 6.2684  | -75.5667 | 9            | 3.7            | 13.25           | 8.5
# ... (2647 rows omitted)

# %%
# Convertir tu tabla datascience a pandas
data_arboles = arboles_udea.select('Y', 'X', 'Nombre común').to_df()

# %%
data_arboles = arboles_udea.select('Y', 'X', 'Nombre común').to_df()
# Crear mapa
fig = px.scatter_mapbox(
    data_arboles,
    lat='X',
    lon='Y',
    hover_name='Nombre común',
    color_discrete_sequence=['green'],
    zoom=16,
    height=600,
    title='Mapa interactivo de árboles sobre OpenStreetMap'
)
# Configurar estilo base (gratuito)
fig.update_layout(mapbox_style='open-street-map')
fig.show()
