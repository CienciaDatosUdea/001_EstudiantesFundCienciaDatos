# %%
from datascience import *
import numpy as np
import matplotlib.pylab as plots
plots.style.use('fivethirtyeight')
# %matplotlib inline

# %% [markdown]
# # Estimación de la Media y la Desviación Estándar Poblacional
#
# Usando la muestra de datos `Notas_sample.csv`, realiza un análisis inferencial para estimar los parámetros poblacionales fundamentales:
#
# - La **media verdadera** de las notas.
# - La **desviación estándar verdadera** de la población.
#
# A partir de esta muestra, realiza lo siguiente:
#
# 1. Construye una **distribución de remuestreo (bootstrap)** tomando muestras con reemplazo del mismo tamaño que la muestra original.
# 2. Calcula la **distribución bootstrap de la media** y la **distribución bootstrap de la desviación estándar**.
# 3. A partir de ambas distribuciones, determina:
#    - La **estimación puntual** de la media poblacional y de la desviación estándar poblacional.
#    - Un **intervalo de confianza del 95%** para cada parámetro.
# 4. Interpreta los resultados a la luz del **Teorema del Límite Central (TLC)**:
#    - Explica por qué la distribución de las **medias muestrales** tiende a ser aproximadamente normal, incluso si la distribución original de las notas no lo es.
#    - Comenta cómo esta propiedad respalda la validez de los intervalos de confianza obtenidos.
